# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawhidrahman292/Tawhidrahman292/blob/main/First_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Welcome Program**

# %%
print("welcome to skill morph")
# Out:
# welcome to skill morph

# %% [markdown]
# ## **2nd section**
